# %%
import newgrading2
import importlib
importlib.reload(newgrading2)
x = newgrading2.PrepareGrading(maxpoints = [20,10,10,20,20,10,10], 
                   main_dir = None, 
                   gradebook = "gradebook.csv", 
                   init_grading_data=False)

# %%
x.prepare_grading()
# Out:
# Reading scanned files...
#
# Reading file:  missing_data.pdf
# File: /Users/bb/Documents/GitHub/QR_Grading/grading2/scans/missing_data.pdf
# Page: 1
# QR code not found.
#
# Enter the exam code or 's' to skip for now: MTH-309T-F19-EX1-002-P00
# MTH-309T-F19-EX1-002-P00
#
# Adding score tables...
#
# Score tables added
#
#
# Assembling files for grading...
#
#
#
# Finishing...
#
# Grading files ready.

# %%
import newgrading2
import importlib
importlib.reload(newgrading2)
x = newgrading2.ReadScores(main_dir = None, 
                           gradebook = "gradebook.csv", 
                           init_grading_data=False)

# %%
x.get_scores(save=True, new_gradebook = "TEST.csv")
# Out:
# Processing: MTH-309T-F19-EX1_problem_7.pdf
# (                     prob_1 prob_2 prob_3 prob_4 prob_5 prob_6 prob_7  total
#  MTH-309T-F19-EX1-001      7      2      0     12     20      5      7     53
#  MTH-309T-F19-EX1-002      4     10     10      0      3      7      4     38
#  MTH-309T-F19-EX1-003     20      5      7      8      5     10      0     55
#  MTH-309T-F19-EX1-004      8      0      2      9      2   NONE      9     30
#  MTH-309T-F19-EX1-005     12      1      0      5      5      9   NONE     32
#  ...                     ...    ...    ...    ...    ...    ...    ...    ...
#  MTH-309T-F19-EX1-084   NONE   NONE   NONE   NONE   NONE   NONE   NONE      0
#  MTH-309T-F19-EX1-085   NONE   NONE   NONE   NONE   NONE   NONE   NONE      0
#  MTH-309T-F19-EX1-086   NONE   NONE   NONE   NONE   NONE   NONE   NONE      0
#  MTH-309T-F19-EX1-088   NONE   NONE   NONE   NONE   NONE   NONE   NONE      0
#  MTH-309T-F19-EX1-089   NONE   NONE   NONE   NONE   NONE   NONE   NONE      0
#
#  [88 rows x 8 columns],
#      person_number               qr_code  email         prob_1 prob_2 prob_3  \
#  0        37581073  MTH-309T-F19-EX1-084    NaN           NONE   NONE   NONE
#  1        50129466  MTH-309T-F19-EX1-085    NaN           NONE   NONE   NONE
#  2        50139133  MTH-309T-F19-EX1-038    NaN           NONE   NONE   NONE
#  3        50139363  MTH-309T-F19-EX1-033    NaN           NONE   NONE   NONE
#  4        50152581  MTH-309T-F19-EX1-009    NaN             10      6      4
#  ..            ...                   ...    ...            ...    ...    ...
#  91       50317450  MTH-309T-F19-EX1-030    NaN           NONE   NONE   NONE
#  92       50320253  MTH-309T-F19-EX1-047    NaN           NONE   NONE   NONE
#  93       50320796  MTH-309T-F19-EX1-083    NaN           NONE   NONE   NONE
#  94       50239786  MTH-309T-F19-EX1-002    NaN              4     10     10
#  95       50208783  MTH-309T-F19-EX1-017    NaN  MULTI: [1, 2]   NONE   NONE
#
#     prob_4 prob_5 prob_6         prob_7  total grade
#  0    NONE   NONE   NONE           NONE      0
#  1    NONE   NONE   NONE           NONE      0
#  2    NONE   NONE   NONE           NONE      0
#  3    NONE   NONE   NONE           NONE      0
#  4       9     12      6  MULTI: [2, 7]     47
#  ..    ...    ...    ...            ...    ...   ...
#  91   NONE   NONE   NONE           NONE      0
#  92   NONE   NONE   NONE           NONE      0
#  93   NONE   NONE   NONE           NONE      0
#  94      0      3      7              4     38
#  95   NONE   NONE   NONE           NONE      0
#
#  [96 rows x 12 columns])

# %%
import newgrading2
import importlib
importlib.reload(newgrading2)
x = newgrading2.AssembleGradedExams(main_dir = None, 
                           gradebook = "TEST.csv", 
                           init_grading_data=False)

# %%
x.assemble_by_student()
# Out:
# Adding score tables...
# Score tables added.
# Adding score marks...
# Score marks added.
# Assembling exams...
# Graded exams ready.

# %%
import newgrading2
import importlib
importlib.reload(newgrading2)
x = newgrading2.EmailGradedExams(main_dir = None, 
                           template = "email_template.txt",
                           gradebook = "new_gradebook.csv", 
                           init_grading_data=False)

# %%
x.send_exams(send_sample=True)
# Out:
# Sending a sample message.
#
# Enter email's subject: exam test
# UB login name: badzioch
# badzioch password:········
# badzioch@buffalo.edu           *********** SENT
# ***FINISHED***

# %%
x = ['a', 'b', 'c']
x.remove('c')

# %%
x
# Out:
# ['a', 'b']

# %%
import glob
glob.glob('*est_page.pdf')
# Out:
# ['test_page.pdf']
