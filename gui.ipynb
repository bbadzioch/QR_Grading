# %%
from PySide2 import QtCore, QtGui

def gui_fname(dir=None):
    """Select a file via a dialog and return the file name.
    """
    if dir is None: dir ='./'
    fname = QtGui.QFileDialog.getOpenFileName(None, "Select data file...", 
            dir, filter="All files (*);; SM Files (*.sm)")
    return fname[0]

gui_fname()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-7a93d2264867> in <module>
#       9     return fname[0]
#      10
# ---> 11 gui_fname()
#
# <ipython-input-1-7a93d2264867> in gui_fname(dir)
#       5     """
#       6     if dir is None: dir ='./'
# ----> 7     fname = QtGui.QFileDialog.getOpenFileName(None, "Select data file...",
#       8             dir, filter="All files (*);; SM Files (*.sm)")
#       9     return fname[0]
#
# AttributeError: module 'PySide2.QtGui' has no attribute 'QFileDialog'

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-e836de25258d> in <module>
# ----> 1 gui_fname()
#
# <ipython-input-4-14036f057fa2> in gui_fname(dir)
#       5     """
#       6     if dir is None: dir ='./'
# ----> 7     fname = QtGui.QFileDialog.getOpenFileName(None, "Select data file...",
#       8             dir, filter="All files (*);; SM Files (*.sm)")
#       9     return fname[0]
#
# AttributeError: module 'PySide2.QtGui' has no attribute 'QFileDialog'

# %%
# %gui qt

from PyQt5.QtWidgets import QFileDialog

def gui_fname(dir=None):
    """Select a file via a dialog and return the file name."""
    if dir is None: dir ='./'
    fname = QFileDialog.getOpenFileName(None, "Select data file...", 
                dir, filter="All files (*);; SM Files (*.sm)")
    return fname[0]

# %%
x = gui_fname()

# %%
x
# Out:
# '/Users/bb/bin/make309_f2018'

# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
